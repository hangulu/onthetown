# %% [markdown]
# ### Evaluation of Search Algorithms
# This notebook allows us to evaluate the five search algorithms used in the On The Town application. They are:
# * Depth-First Search
# * Breadth-First Search
# * Greedy Search
# * Uniform Cost Search
# * A Star Search

# %%
from center import *
import algorithms as alg
import random
from contextlib import contextmanager
import signal
import time
import numpy as np
import pandas as pd

# %%
def randomParty(num):
    coordlist = [(40.503780, -74.257985), (40.910901, -73.908623), (40.742613, -73.709127),
                (40.597664, -73.763148), (40.612447, -74.090254), (40.770627, -73.958057),
                (40.754135, -73.872459), (40.718946, -73.808422), (40.665516, -73.868019),
                (40.653366, -73.970087), (40.661236, -73.742950), (40.560440, -73.920751)]
    typelist = ["bar", "restaurant", "night_club", "movie_theater", "cafe"]
    party = Party()
    coords = []
    for i in range(num):
        coord = coordlist[np.random.randint(0,len(coordlist))]
        while coord in coords:
            coord = coordlist[np.random.randint(0,len(coordlist))]
        coords.append(coord)
    for i in range(num):
        username = "User" + str(i)
        coord = coords[np.random.randint(0,len(coords))]
        rating = 2 + 3*np.random.random_sample()
        price = np.random.randint(1,5)
        types = np.random.choice(typelist,size = np.random.randint(1,4),replace = False)
        user = User(username, coord[0], coord[1], price, rating, types)
        party.addToParty(user)
    party.updateAll()
    return party

# %%
class TimeoutException(Exception): pass

@contextmanager
def time_limit(seconds):
    def signal_handler(signum, frame):
        raise TimeoutException("Timed out!")
    signal.signal(signal.SIGALRM, signal_handler)
    signal.alarm(seconds)
    try:
        yield
    finally:
        signal.alarm(0)

# %%
algs = alg.Algorithm(None, None, None)

test_log = []
pnum = 300
for i in range(pnum):
    print("Starting simulation " + str(i) + ".")
    # Initialize a random party, of size between 2 and 6 inclusive
    party_size = np.random.randint(2,7)
    party = randomParty(party_size)
    
    # Perform DFS and record the sadness and time
    start_time = time.time()
    # Limit the test to 1 minute
    try:
        with time_limit(60): # 1 minute time limit
            raw_dfs = algs.dfsSearch(party)
            if raw_dfs:
                dfs_sadness = algs.dfsSearch(party)[1] / (party_size + 1)
                print("DFS simulation " + str(i) + " complete.")
            else:
                dfs_sadness = None
                print("DFS simulation " + str(i) + " encountered an empty list.")
    except TimeoutException as e:
        # If timed out
        dfs_sadness = None
        print("DFS simulation " + str(i) + " timed out.")
    dfs_elapsed_time = time.time() - start_time

    # Perform BFS and record the sadness and time
    start_time = time.time()
    try:
        with time_limit(60): # 1 minute time limit
            raw_bfs = algs.bfsSearch(party)
            if raw_bfs:
                bfs_sadness = algs.bfsSearch(party)[1] / (party_size + 1)
                print("BFS simulation " + str(i) + " complete.")
            else:
                bfs_sadness = None
                print("BFS simulation " + str(i) + " encountered an empty list.")
    except TimeoutException as e:
        # If timed out
        bfs_sadness = None
        print("BFS simulation " + str(i) + " timed out.")
    bfs_elapsed_time = time.time() - start_time

    # Perform Greedy Search and record the sadness and time
    start_time = time.time()
    try:
        with time_limit(60): # 1 minute time limit
            raw_greedy = algs.greedySearch(party)
            if raw_greedy:
                greedy_sadness = algs.greedySearch(party)[1] / (party_size + 1)
                print("Greedy simulation " + str(i) + " complete.")
            else:
                greedy_sadness = None
                print("Greedy simulation " + str(i) + " encountered an empty list.")
    except TimeoutException as e:
        # If timed out
        greedy_sadness = None
        print("Greedy simulation " + str(i) + " timed out.")
    greedy_elapsed_time = time.time() - start_time

    # Perform UCS and record the sadness and time
    start_time = time.time()
    try:
        with time_limit(60): # 1 minute time limit
            raw_ucs = algs.ucsSearch(party)
            if raw_ucs:
                ucs_sadness = algs.ucsSearch(party)[1] / (party_size + 1)
                print("UCS simulation " + str(i) + " complete.")
            else:
                ucs_sadness = None
                print("UCS simulation " + str(i) + " encountered an empty list.")
    except TimeoutException as e:
        # If timed out
        ucs_sadness = None
        print("UCS simulation " + str(i) + " timed out.")
    ucs_elapsed_time = time.time() - start_time

    # Perform A* Search and record the sadness and time
    start_time = time.time()
    try:
        with time_limit(60): # 1 minute time limit
            raw_astar = algs.astarSearch(party)
            if raw_astar:
                astar_sadness = algs.astarSearch(party)[1] / (party_size + 1)
                print("A* simulation " + str(i) + " complete.")
            else:
                astar_sadness = None
                print("A* simulation " + str(i) + " encountered an empty list.")
    except TimeoutException as e:
        # If timed out
        astar_sadness = None
        print("A* simulation " + str(i) + " timed out.")
    astar_elapsed_time = time.time() - start_time
    
    result = {"party_size": party_size, 
              "dfs_sad": dfs_sadness, 
              "dfs_time": dfs_elapsed_time, 
              "bfs_sad": bfs_sadness, 
              "bfs_time": bfs_elapsed_time, 
              "greedy_sad": greedy_sadness, 
              "greedy_time": greedy_elapsed_time, 
              "ucs_sad": ucs_sadness, 
              "ucs_time": ucs_elapsed_time, 
              "astar_sad": astar_sadness, 
              "astar_time": astar_elapsed_time}
    
    test_log.append(result)
    print("Simulation " + str(i) + " complete.\n")
# Out:
# Starting simulation 0.
# DFS simulation 0 complete.
# BFS simulation 0 timed out.
# Greedy simulation 0 complete.
# UCS simulation 0 complete.
# A* simulation 0 complete.
# Simulation 0 complete.
#
# Starting simulation 1.
# DFS simulation 1 encountered an empty list.
# BFS simulation 1 timed out.
# Greedy simulation 1 complete.
# UCS simulation 1 complete.
# A* simulation 1 complete.
# Simulation 1 complete.
#
# Starting simulation 2.
# DFS simulation 2 encountered an empty list.
# BFS simulation 2 complete.
# Greedy simulation 2 complete.
# UCS simulation 2 complete.
# A* simulation 2 complete.
# Simulation 2 complete.
#
# Starting simulation 3.
# DFS simulation 3 complete.
# BFS simulation 3 timed out.
# Greedy simulation 3 complete.
# UCS simulation 3 complete.
# A* simulation 3 complete.
# Simulation 3 complete.
#
# Starting simulation 4.
# DFS simulation 4 complete.
# BFS simulation 4 timed out.
# Greedy simulation 4 complete.
# UCS simulation 4 complete.
# A* simulation 4 complete.
# Simulation 4 complete.
#
# Starting simulation 5.
# DFS simulation 5 complete.
# BFS simulation 5 timed out.
# Greedy simulation 5 complete.
# UCS simulation 5 complete.
# A* simulation 5 complete.
# Simulation 5 complete.
#
# Starting simulation 6.
# DFS simulation 6 encountered an empty list.
# BFS simulation 6 encountered an empty list.
# Greedy simulation 6 encountered an empty list.
# UCS simulation 6 encountered an empty list.
# A* simulation 6 encountered an empty list.
# Simulation 6 complete.
#
# Starting simulation 7.
# DFS simulation 7 complete.
# BFS simulation 7 complete.
# Greedy simulation 7 complete.
# UCS simulation 7 complete.
# A* simulation 7 complete.
# Simulation 7 complete.
#
# Starting simulation 8.
# DFS simulation 8 complete.
# BFS simulation 8 timed out.
# Greedy simulation 8 complete.
# UCS simulation 8 complete.
# A* simulation 8 complete.
# Simulation 8 complete.
#
# Starting simulation 9.
# DFS simulation 9 encountered an empty list.
# BFS simulation 9 timed out.
# Greedy simulation 9 complete.
# UCS simulation 9 complete.
# A* simulation 9 complete.
# Simulation 9 complete.
#
# Starting simulation 10.
# DFS simulation 10 complete.
# BFS simulation 10 timed out.
# Greedy simulation 10 complete.
# UCS simulation 10 complete.
# A* simulation 10 complete.
# Simulation 10 complete.
#
# Starting simulation 11.
# DFS simulation 11 complete.
# BFS simulation 11 timed out.
# Greedy simulation 11 complete.
# UCS simulation 11 complete.
# A* simulation 11 complete.
# Simulation 11 complete.
#
# Starting simulation 12.
# DFS simulation 12 complete.
# BFS simulation 12 timed out.
# Greedy simulation 12 complete.
# UCS simulation 12 complete.
# A* simulation 12 complete.
# Simulation 12 complete.
#
# Starting simulation 13.
# DFS simulation 13 complete.
# BFS simulation 13 timed out.
# Greedy simulation 13 complete.
# UCS simulation 13 timed out.
# A* simulation 13 complete.
# Simulation 13 complete.
#
# Starting simulation 14.
# DFS simulation 14 complete.
# BFS simulation 14 timed out.
# Greedy simulation 14 complete.
# UCS simulation 14 complete.
# A* simulation 14 complete.
# Simulation 14 complete.
#
# Starting simulation 15.
# DFS simulation 15 complete.
# BFS simulation 15 timed out.
# Greedy simulation 15 complete.
# UCS simulation 15 complete.
# A* simulation 15 complete.
# Simulation 15 complete.
#
# Starting simulation 16.
# DFS simulation 16 complete.
# BFS simulation 16 timed out.
# Greedy simulation 16 complete.
# UCS simulation 16 complete.
# A* simulation 16 complete.
# Simulation 16 complete.
#
# Starting simulation 17.
# DFS simulation 17 complete.
# BFS simulation 17 timed out.
# Greedy simulation 17 complete.
# UCS simulation 17 complete.
# A* simulation 17 complete.
# Simulation 17 complete.
#
# Starting simulation 18.
# DFS simulation 18 complete.
# BFS simulation 18 timed out.
# Greedy simulation 18 complete.
# UCS simulation 18 complete.
# A* simulation 18 complete.
# Simulation 18 complete.
#
# Starting simulation 19.
# DFS simulation 19 complete.
# BFS simulation 19 timed out.
# Greedy simulation 19 complete.
# UCS simulation 19 complete.
# A* simulation 19 complete.
# Simulation 19 complete.
#
# Starting simulation 20.
# DFS simulation 20 complete.
# BFS simulation 20 timed out.
# Greedy simulation 20 complete.
# UCS simulation 20 complete.
# A* simulation 20 complete.
# Simulation 20 complete.
#
# Starting simulation 21.
# DFS simulation 21 encountered an empty list.
# BFS simulation 21 complete.
# Greedy simulation 21 complete.
# UCS simulation 21 complete.
# A* simulation 21 complete.
# Simulation 21 complete.
#
# Starting simulation 22.
# DFS simulation 22 encountered an empty list.
# BFS simulation 22 complete.
# Greedy simulation 22 complete.
# UCS simulation 22 complete.
# A* simulation 22 complete.
# Simulation 22 complete.
#
# Starting simulation 23.
# DFS simulation 23 complete.
# BFS simulation 23 complete.
# Greedy simulation 23 complete.
# UCS simulation 23 complete.
# A* simulation 23 complete.
# Simulation 23 complete.
#
# Starting simulation 24.
# DFS simulation 24 complete.
# BFS simulation 24 timed out.
# Greedy simulation 24 complete.
# UCS simulation 24 complete.
# A* simulation 24 complete.
# Simulation 24 complete.
#
# Starting simulation 25.
# DFS simulation 25 complete.
# BFS simulation 25 timed out.
# Greedy simulation 25 complete.
# UCS simulation 25 complete.
# A* simulation 25 complete.
# Simulation 25 complete.
#
# Starting simulation 26.
# DFS simulation 26 encountered an empty list.
# BFS simulation 26 encountered an empty list.
# Greedy simulation 26 encountered an empty list.
# UCS simulation 26 encountered an empty list.
# A* simulation 26 encountered an empty list.
# Simulation 26 complete.
#
# Starting simulation 27.
# DFS simulation 27 complete.
# BFS simulation 27 timed out.
# Greedy simulation 27 complete.
# UCS simulation 27 complete.
# A* simulation 27 complete.
# Simulation 27 complete.
#
# Starting simulation 28.
# DFS simulation 28 complete.
# BFS simulation 28 timed out.
# Greedy simulation 28 complete.
# UCS simulation 28 complete.
# A* simulation 28 complete.
# Simulation 28 complete.
#
# Starting simulation 29.
# DFS simulation 29 complete.
# BFS simulation 29 timed out.
# Greedy simulation 29 complete.
# UCS simulation 29 complete.
# A* simulation 29 complete.
# Simulation 29 complete.
#
# Starting simulation 30.
# DFS simulation 30 complete.
# BFS simulation 30 timed out.
# Greedy simulation 30 complete.
# UCS simulation 30 complete.
# A* simulation 30 complete.
# Simulation 30 complete.
#
# Starting simulation 31.
# DFS simulation 31 complete.
# BFS simulation 31 timed out.
# Greedy simulation 31 complete.
# UCS simulation 31 complete.
# A* simulation 31 complete.
# Simulation 31 complete.
#
# Starting simulation 32.
# DFS simulation 32 encountered an empty list.
# BFS simulation 32 encountered an empty list.
# Greedy simulation 32 encountered an empty list.
# UCS simulation 32 encountered an empty list.
# A* simulation 32 encountered an empty list.
# Simulation 32 complete.
#
# Starting simulation 33.
# DFS simulation 33 complete.
# BFS simulation 33 timed out.
# Greedy simulation 33 complete.
# UCS simulation 33 complete.
# A* simulation 33 complete.
# Simulation 33 complete.
#
# Starting simulation 34.
# DFS simulation 34 complete.
# BFS simulation 34 timed out.
# Greedy simulation 34 complete.
# UCS simulation 34 complete.
# A* simulation 34 complete.
# Simulation 34 complete.
#
# Starting simulation 35.
# DFS simulation 35 complete.
# BFS simulation 35 timed out.
# Greedy simulation 35 complete.
# UCS simulation 35 complete.
# A* simulation 35 complete.
# Simulation 35 complete.
#
# Starting simulation 36.
# DFS simulation 36 complete.
# BFS simulation 36 timed out.
# Greedy simulation 36 complete.
# UCS simulation 36 complete.
# A* simulation 36 complete.
# Simulation 36 complete.
#
# Starting simulation 37.
# DFS simulation 37 complete.
# BFS simulation 37 timed out.
# Greedy simulation 37 complete.
# UCS simulation 37 complete.
# A* simulation 37 complete.
# Simulation 37 complete.
#
# Starting simulation 38.
# DFS simulation 38 complete.
# BFS simulation 38 timed out.
# Greedy simulation 38 complete.
# UCS simulation 38 complete.
# A* simulation 38 complete.
# Simulation 38 complete.
#
# Starting simulation 39.
# DFS simulation 39 complete.
# BFS simulation 39 timed out.
# Greedy simulation 39 complete.
# UCS simulation 39 complete.
# A* simulation 39 complete.
# Simulation 39 complete.
#
# Starting simulation 40.
# DFS simulation 40 encountered an empty list.
# BFS simulation 40 encountered an empty list.
# Greedy simulation 40 encountered an empty list.
# UCS simulation 40 encountered an empty list.
# A* simulation 40 encountered an empty list.
# Simulation 40 complete.
#
# Starting simulation 41.
# DFS simulation 41 encountered an empty list.
# BFS simulation 41 complete.
# Greedy simulation 41 complete.
# UCS simulation 41 complete.
# A* simulation 41 complete.
# Simulation 41 complete.
#
# Starting simulation 42.
# DFS simulation 42 complete.
# BFS simulation 42 timed out.
# Greedy simulation 42 complete.
# UCS simulation 42 complete.
# A* simulation 42 complete.
# Simulation 42 complete.
#
# Starting simulation 43.
# DFS simulation 43 complete.
# BFS simulation 43 timed out.
# Greedy simulation 43 complete.
# UCS simulation 43 complete.
# A* simulation 43 complete.
# Simulation 43 complete.
#
# Starting simulation 44.
# DFS simulation 44 encountered an empty list.
# BFS simulation 44 encountered an empty list.
# Greedy simulation 44 encountered an empty list.
# UCS simulation 44 encountered an empty list.
# A* simulation 44 encountered an empty list.
# Simulation 44 complete.
#
# Starting simulation 45.
# DFS simulation 45 complete.
# BFS simulation 45 timed out.
# Greedy simulation 45 complete.
# UCS simulation 45 complete.
# A* simulation 45 complete.
# Simulation 45 complete.
#
# Starting simulation 46.
# DFS simulation 46 complete.
# BFS simulation 46 timed out.
# Greedy simulation 46 complete.
# UCS simulation 46 complete.
# A* simulation 46 complete.
# Simulation 46 complete.
#
# Starting simulation 47.
# DFS simulation 47 complete.
# BFS simulation 47 timed out.
# Greedy simulation 47 complete.
# UCS simulation 47 complete.
# A* simulation 47 complete.
# Simulation 47 complete.
#
# Starting simulation 48.
# DFS simulation 48 complete.
# BFS simulation 48 timed out.
# Greedy simulation 48 complete.
# UCS simulation 48 complete.
# A* simulation 48 complete.
# Simulation 48 complete.
#
# Starting simulation 49.
# DFS simulation 49 complete.
# BFS simulation 49 timed out.
# Greedy simulation 49 complete.
# UCS simulation 49 complete.
# A* simulation 49 complete.
# Simulation 49 complete.
#
# Starting simulation 50.
# DFS simulation 50 complete.
# BFS simulation 50 timed out.
# Greedy simulation 50 complete.
# UCS simulation 50 complete.
# A* simulation 50 complete.
# Simulation 50 complete.
#
# Starting simulation 51.
# DFS simulation 51 complete.
# BFS simulation 51 timed out.
# Greedy simulation 51 complete.
# UCS simulation 51 timed out.
# A* simulation 51 complete.
# Simulation 51 complete.
#
# Starting simulation 52.
# DFS simulation 52 complete.
# BFS simulation 52 timed out.
# Greedy simulation 52 complete.
# UCS simulation 52 complete.
# A* simulation 52 complete.
# Simulation 52 complete.
#
# Starting simulation 53.
# DFS simulation 53 complete.
# BFS simulation 53 timed out.
# Greedy simulation 53 complete.
# UCS simulation 53 complete.
# A* simulation 53 complete.
# Simulation 53 complete.
#
# Starting simulation 54.
# DFS simulation 54 complete.
# BFS simulation 54 complete.
# Greedy simulation 54 complete.
# UCS simulation 54 complete.
# A* simulation 54 complete.
# Simulation 54 complete.
#
# Starting simulation 55.
# DFS simulation 55 complete.
# BFS simulation 55 timed out.
# Greedy simulation 55 complete.
# UCS simulation 55 complete.
# A* simulation 55 complete.
# Simulation 55 complete.
#
# Starting simulation 56.
# DFS simulation 56 complete.
# BFS simulation 56 timed out.
# Greedy simulation 56 complete.
# UCS simulation 56 complete.
# A* simulation 56 complete.
# Simulation 56 complete.
#
# Starting simulation 57.
# DFS simulation 57 complete.
# BFS simulation 57 timed out.
# Greedy simulation 57 complete.
# UCS simulation 57 complete.
# A* simulation 57 complete.
# Simulation 57 complete.
#
# Starting simulation 58.
# DFS simulation 58 complete.
# BFS simulation 58 timed out.
# Greedy simulation 58 complete.
# UCS simulation 58 complete.
# A* simulation 58 complete.
# Simulation 58 complete.
#
# Starting simulation 59.
# DFS simulation 59 complete.
# BFS simulation 59 timed out.
# Greedy simulation 59 complete.
# UCS simulation 59 complete.
# A* simulation 59 complete.
# Simulation 59 complete.
#
# Starting simulation 60.
# DFS simulation 60 complete.
# BFS simulation 60 timed out.
# Greedy simulation 60 complete.
# UCS simulation 60 complete.
# A* simulation 60 complete.
# Simulation 60 complete.
#
# Starting simulation 61.
# DFS simulation 61 complete.
# BFS simulation 61 timed out.
# Greedy simulation 61 complete.
# UCS simulation 61 complete.
# A* simulation 61 complete.
# Simulation 61 complete.
#
# Starting simulation 62.
# DFS simulation 62 complete.
# BFS simulation 62 timed out.
# Greedy simulation 62 complete.
# UCS simulation 62 complete.
# A* simulation 62 complete.
# Simulation 62 complete.
#
# Starting simulation 63.
# DFS simulation 63 complete.
# BFS simulation 63 timed out.
# Greedy simulation 63 complete.
# UCS simulation 63 complete.
# A* simulation 63 complete.
# Simulation 63 complete.
#
# Starting simulation 64.
# DFS simulation 64 complete.
# BFS simulation 64 timed out.
# Greedy simulation 64 complete.
# UCS simulation 64 complete.
# A* simulation 64 complete.
# Simulation 64 complete.
#
# Starting simulation 65.
# DFS simulation 65 complete.
# BFS simulation 65 timed out.
# Greedy simulation 65 complete.
# UCS simulation 65 complete.
# A* simulation 65 complete.
# Simulation 65 complete.
#
# Starting simulation 66.
# DFS simulation 66 complete.
# BFS simulation 66 timed out.
# Greedy simulation 66 complete.
# UCS simulation 66 complete.
# A* simulation 66 complete.
# Simulation 66 complete.
#
# Starting simulation 67.
# DFS simulation 67 complete.
# BFS simulation 67 timed out.
# Greedy simulation 67 complete.
# UCS simulation 67 complete.
# A* simulation 67 complete.
# Simulation 67 complete.
#
# Starting simulation 68.
# DFS simulation 68 complete.
# BFS simulation 68 timed out.
# Greedy simulation 68 complete.
# UCS simulation 68 timed out.
# A* simulation 68 complete.
# Simulation 68 complete.
#
# Starting simulation 69.
# DFS simulation 69 complete.
# BFS simulation 69 timed out.
# Greedy simulation 69 complete.
# UCS simulation 69 complete.
# A* simulation 69 complete.
# Simulation 69 complete.
#
# Starting simulation 70.
# DFS simulation 70 complete.
# BFS simulation 70 timed out.
# Greedy simulation 70 complete.
# UCS simulation 70 complete.
# A* simulation 70 complete.
# Simulation 70 complete.
#
# Starting simulation 71.
# DFS simulation 71 encountered an empty list.
# BFS simulation 71 encountered an empty list.
# Greedy simulation 71 encountered an empty list.
# UCS simulation 71 encountered an empty list.
# A* simulation 71 encountered an empty list.
# Simulation 71 complete.
#
# Starting simulation 72.
# DFS simulation 72 complete.
# BFS simulation 72 timed out.
# Greedy simulation 72 complete.
# UCS simulation 72 complete.
# A* simulation 72 complete.
# Simulation 72 complete.
#
# Starting simulation 73.
# DFS simulation 73 complete.
# BFS simulation 73 complete.
# Greedy simulation 73 complete.
# UCS simulation 73 complete.
# A* simulation 73 complete.
# Simulation 73 complete.
#
# Starting simulation 74.
# DFS simulation 74 complete.
# BFS simulation 74 complete.
# Greedy simulation 74 complete.
# UCS simulation 74 complete.
# A* simulation 74 complete.
# Simulation 74 complete.
#
# Starting simulation 75.
# DFS simulation 75 complete.
# BFS simulation 75 complete.
# Greedy simulation 75 complete.
# UCS simulation 75 complete.
# A* simulation 75 complete.
# Simulation 75 complete.
#
# Starting simulation 76.
# DFS simulation 76 complete.
# BFS simulation 76 timed out.
# Greedy simulation 76 complete.
# UCS simulation 76 complete.
# A* simulation 76 complete.
# Simulation 76 complete.
#
# Starting simulation 77.
# DFS simulation 77 complete.
# BFS simulation 77 timed out.
# Greedy simulation 77 complete.
# UCS simulation 77 complete.
# A* simulation 77 complete.
# Simulation 77 complete.
#
# Starting simulation 78.
# DFS simulation 78 complete.
# BFS simulation 78 timed out.
# Greedy simulation 78 complete.
# UCS simulation 78 complete.
# A* simulation 78 complete.
# Simulation 78 complete.
#
# Starting simulation 79.
# DFS simulation 79 complete.
# BFS simulation 79 timed out.
# Greedy simulation 79 complete.
# UCS simulation 79 complete.
# A* simulation 79 complete.
# Simulation 79 complete.
#
# Starting simulation 80.
# DFS simulation 80 complete.
# BFS simulation 80 timed out.
# Greedy simulation 80 complete.
# UCS simulation 80 complete.
# A* simulation 80 complete.
# Simulation 80 complete.
#
# Starting simulation 81.
# DFS simulation 81 complete.
# BFS simulation 81 timed out.
# Greedy simulation 81 complete.
# UCS simulation 81 complete.
# A* simulation 81 complete.
# Simulation 81 complete.
#
# Starting simulation 82.
# DFS simulation 82 complete.
# BFS simulation 82 timed out.
# Greedy simulation 82 complete.
# UCS simulation 82 complete.
# A* simulation 82 complete.
# Simulation 82 complete.
#
# Starting simulation 83.
# DFS simulation 83 complete.
# BFS simulation 83 complete.
# Greedy simulation 83 complete.
# UCS simulation 83 complete.
# A* simulation 83 complete.
# Simulation 83 complete.
#
# Starting simulation 84.
# DFS simulation 84 complete.
# BFS simulation 84 timed out.
# Greedy simulation 84 complete.
# UCS simulation 84 complete.
# A* simulation 84 complete.
# Simulation 84 complete.
#
# Starting simulation 85.
# DFS simulation 85 complete.
# BFS simulation 85 timed out.
# Greedy simulation 85 complete.
# UCS simulation 85 complete.
# A* simulation 85 complete.
# Simulation 85 complete.
#
# Starting simulation 86.
# DFS simulation 86 complete.
# BFS simulation 86 timed out.
# Greedy simulation 86 complete.
# UCS simulation 86 complete.
# A* simulation 86 complete.
# Simulation 86 complete.
#
# Starting simulation 87.
# DFS simulation 87 complete.
# BFS simulation 87 timed out.
# Greedy simulation 87 complete.
# UCS simulation 87 complete.
# A* simulation 87 complete.
# Simulation 87 complete.
#
# Starting simulation 88.
# DFS simulation 88 complete.
# BFS simulation 88 timed out.
# Greedy simulation 88 complete.
# UCS simulation 88 complete.
# A* simulation 88 complete.
# Simulation 88 complete.
#
# Starting simulation 89.
# DFS simulation 89 complete.
# BFS simulation 89 timed out.
# Greedy simulation 89 complete.
# UCS simulation 89 complete.
# A* simulation 89 complete.
# Simulation 89 complete.
#
# Starting simulation 90.
# DFS simulation 90 complete.
# BFS simulation 90 timed out.
# Greedy simulation 90 complete.
# UCS simulation 90 complete.
# A* simulation 90 complete.
# Simulation 90 complete.
#
# Starting simulation 91.
# DFS simulation 91 encountered an empty list.
# BFS simulation 91 encountered an empty list.
# Greedy simulation 91 encountered an empty list.
# UCS simulation 91 encountered an empty list.
# A* simulation 91 encountered an empty list.
# Simulation 91 complete.
#
# Starting simulation 92.
# DFS simulation 92 complete.
# BFS simulation 92 complete.
# Greedy simulation 92 complete.
# UCS simulation 92 complete.
# A* simulation 92 complete.
# Simulation 92 complete.
#
# Starting simulation 93.
# DFS simulation 93 encountered an empty list.
# BFS simulation 93 complete.
# Greedy simulation 93 complete.
# UCS simulation 93 complete.
# A* simulation 93 complete.
# Simulation 93 complete.
#
# Starting simulation 94.
# DFS simulation 94 complete.
# BFS simulation 94 timed out.
# Greedy simulation 94 complete.
# UCS simulation 94 complete.
# A* simulation 94 complete.
# Simulation 94 complete.
#
# Starting simulation 95.
# DFS simulation 95 complete.
# BFS simulation 95 timed out.
# Greedy simulation 95 complete.
# UCS simulation 95 complete.
# A* simulation 95 complete.
# Simulation 95 complete.
#
# Starting simulation 96.
# DFS simulation 96 complete.
# BFS simulation 96 timed out.
# Greedy simulation 96 complete.
# UCS simulation 96 complete.
# A* simulation 96 complete.
# Simulation 96 complete.
#
# Starting simulation 97.
# DFS simulation 97 complete.
# BFS simulation 97 complete.
# Greedy simulation 97 complete.
# UCS simulation 97 complete.
# A* simulation 97 complete.
# Simulation 97 complete.
#
# Starting simulation 98.
# DFS simulation 98 complete.
# BFS simulation 98 timed out.
# Greedy simulation 98 complete.
# UCS simulation 98 complete.
# A* simulation 98 complete.
# Simulation 98 complete.
#
# Starting simulation 99.
# DFS simulation 99 complete.
# BFS simulation 99 timed out.
# Greedy simulation 99 complete.
# UCS simulation 99 complete.
# A* simulation 99 complete.
# Simulation 99 complete.
#
# Starting simulation 100.
# DFS simulation 100 complete.
# BFS simulation 100 timed out.
# Greedy simulation 100 complete.
# UCS simulation 100 complete.
# A* simulation 100 complete.
# Simulation 100 complete.
#
# Starting simulation 101.
# DFS simulation 101 complete.
# BFS simulation 101 timed out.
# Greedy simulation 101 complete.
# UCS simulation 101 complete.
# A* simulation 101 complete.
# Simulation 101 complete.
#
# Starting simulation 102.
# DFS simulation 102 complete.
# BFS simulation 102 timed out.
# Greedy simulation 102 complete.
# UCS simulation 102 complete.
# A* simulation 102 complete.
# Simulation 102 complete.
#
# Starting simulation 103.
# DFS simulation 103 complete.
# BFS simulation 103 timed out.
# Greedy simulation 103 complete.
# UCS simulation 103 complete.
# A* simulation 103 complete.
# Simulation 103 complete.
#
# Starting simulation 104.
# DFS simulation 104 complete.
# BFS simulation 104 complete.
# Greedy simulation 104 complete.
# UCS simulation 104 complete.
# A* simulation 104 complete.
# Simulation 104 complete.
#
# Starting simulation 105.
# DFS simulation 105 complete.
# BFS simulation 105 timed out.
# Greedy simulation 105 complete.
# UCS simulation 105 timed out.
# A* simulation 105 complete.
# Simulation 105 complete.
#
# Starting simulation 106.
# DFS simulation 106 encountered an empty list.
# BFS simulation 106 complete.
# Greedy simulation 106 complete.
# UCS simulation 106 complete.
# A* simulation 106 complete.
# Simulation 106 complete.
#
# Starting simulation 107.
# DFS simulation 107 complete.
# BFS simulation 107 timed out.
# Greedy simulation 107 complete.
# UCS simulation 107 timed out.
# A* simulation 107 complete.
# Simulation 107 complete.
#
# Starting simulation 108.
# DFS simulation 108 encountered an empty list.
# BFS simulation 108 encountered an empty list.
# Greedy simulation 108 encountered an empty list.
# UCS simulation 108 encountered an empty list.
# A* simulation 108 encountered an empty list.
# Simulation 108 complete.
#
# Starting simulation 109.
# DFS simulation 109 complete.
# BFS simulation 109 timed out.
# Greedy simulation 109 complete.
# UCS simulation 109 complete.
# A* simulation 109 complete.
# Simulation 109 complete.
#
# Starting simulation 110.
# DFS simulation 110 complete.
# BFS simulation 110 timed out.
# Greedy simulation 110 complete.
# UCS simulation 110 complete.
# A* simulation 110 complete.
# Simulation 110 complete.
#
# Starting simulation 111.
# DFS simulation 111 complete.
# BFS simulation 111 timed out.
# Greedy simulation 111 complete.
# UCS simulation 111 complete.
# A* simulation 111 complete.
# Simulation 111 complete.
#
# Starting simulation 112.
# DFS simulation 112 complete.
# BFS simulation 112 timed out.
# Greedy simulation 112 complete.
# UCS simulation 112 complete.
# A* simulation 112 complete.
# Simulation 112 complete.
#
# Starting simulation 113.
# DFS simulation 113 complete.
# BFS simulation 113 timed out.
# Greedy simulation 113 complete.
# UCS simulation 113 complete.
# A* simulation 113 complete.
# Simulation 113 complete.
#
# Starting simulation 114.
# DFS simulation 114 complete.
# BFS simulation 114 timed out.
# Greedy simulation 114 complete.
# UCS simulation 114 complete.
# A* simulation 114 complete.
# Simulation 114 complete.
#
# Starting simulation 115.
# DFS simulation 115 complete.
# BFS simulation 115 timed out.
# Greedy simulation 115 complete.
# UCS simulation 115 complete.
# A* simulation 115 complete.
# Simulation 115 complete.
#
# Starting simulation 116.
# DFS simulation 116 complete.
# BFS simulation 116 timed out.
# Greedy simulation 116 complete.
# UCS simulation 116 complete.
# A* simulation 116 complete.
# Simulation 116 complete.
#
# Starting simulation 117.
# DFS simulation 117 complete.
# BFS simulation 117 timed out.
# Greedy simulation 117 complete.
# UCS simulation 117 complete.
# A* simulation 117 complete.
# Simulation 117 complete.
#
# Starting simulation 118.
# DFS simulation 118 complete.
# BFS simulation 118 timed out.
# Greedy simulation 118 complete.
# UCS simulation 118 complete.
# A* simulation 118 complete.
# Simulation 118 complete.
#
# Starting simulation 119.
# DFS simulation 119 complete.
# BFS simulation 119 timed out.
# Greedy simulation 119 complete.
# UCS simulation 119 complete.
# A* simulation 119 complete.
# Simulation 119 complete.
#
# Starting simulation 120.
# DFS simulation 120 encountered an empty list.
# BFS simulation 120 complete.
# Greedy simulation 120 complete.
# UCS simulation 120 complete.
# A* simulation 120 complete.
# Simulation 120 complete.
#
# Starting simulation 121.
# DFS simulation 121 complete.
# BFS simulation 121 timed out.
# Greedy simulation 121 complete.
# UCS simulation 121 timed out.
# A* simulation 121 complete.
# Simulation 121 complete.
#
# Starting simulation 122.
# DFS simulation 122 complete.
# BFS simulation 122 timed out.
# Greedy simulation 122 complete.
# UCS simulation 122 complete.
# A* simulation 122 complete.
# Simulation 122 complete.
#
# Starting simulation 123.
# DFS simulation 123 encountered an empty list.
# BFS simulation 123 encountered an empty list.
# Greedy simulation 123 encountered an empty list.
# UCS simulation 123 encountered an empty list.
# A* simulation 123 encountered an empty list.
# Simulation 123 complete.
#
# Starting simulation 124.
# DFS simulation 124 complete.
# BFS simulation 124 timed out.
# Greedy simulation 124 complete.
# UCS simulation 124 complete.
# A* simulation 124 complete.
# Simulation 124 complete.
#
# Starting simulation 125.
# DFS simulation 125 complete.
# BFS simulation 125 timed out.
# Greedy simulation 125 complete.
# UCS simulation 125 complete.
# A* simulation 125 complete.
# Simulation 125 complete.
#
# Starting simulation 126.
# DFS simulation 126 complete.
# BFS simulation 126 timed out.
# Greedy simulation 126 complete.
# UCS simulation 126 complete.
# A* simulation 126 complete.
# Simulation 126 complete.
#
# Starting simulation 127.
# DFS simulation 127 complete.
# BFS simulation 127 timed out.
# Greedy simulation 127 complete.
# UCS simulation 127 complete.
# A* simulation 127 complete.
# Simulation 127 complete.
#
# Starting simulation 128.
# DFS simulation 128 encountered an empty list.
# BFS simulation 128 timed out.
# Greedy simulation 128 complete.
# UCS simulation 128 complete.
# A* simulation 128 complete.
# Simulation 128 complete.
#
# Starting simulation 129.
# DFS simulation 129 encountered an empty list.
# BFS simulation 129 timed out.
# Greedy simulation 129 complete.
# UCS simulation 129 complete.
# A* simulation 129 complete.
# Simulation 129 complete.
#
# Starting simulation 130.
# DFS simulation 130 complete.
# BFS simulation 130 timed out.
# Greedy simulation 130 complete.
# UCS simulation 130 complete.
# A* simulation 130 complete.
# Simulation 130 complete.
#
# Starting simulation 131.
# DFS simulation 131 complete.
# BFS simulation 131 timed out.
# Greedy simulation 131 complete.
# UCS simulation 131 complete.
# A* simulation 131 complete.
# Simulation 131 complete.
#
# Starting simulation 132.
# DFS simulation 132 complete.
# BFS simulation 132 timed out.
# Greedy simulation 132 complete.
# UCS simulation 132 complete.
# A* simulation 132 complete.
# Simulation 132 complete.
#
# Starting simulation 133.
# DFS simulation 133 encountered an empty list.
# BFS simulation 133 encountered an empty list.
# Greedy simulation 133 encountered an empty list.
# UCS simulation 133 encountered an empty list.
# A* simulation 133 encountered an empty list.
# Simulation 133 complete.
#
# Starting simulation 134.
# DFS simulation 134 complete.
# BFS simulation 134 timed out.
# Greedy simulation 134 complete.
# UCS simulation 134 complete.
# A* simulation 134 complete.
# Simulation 134 complete.
#
# Starting simulation 135.
# DFS simulation 135 complete.
# BFS simulation 135 timed out.
# Greedy simulation 135 complete.
# UCS simulation 135 complete.
# A* simulation 135 complete.
# Simulation 135 complete.
#
# Starting simulation 136.
# DFS simulation 136 complete.
# BFS simulation 136 timed out.
# Greedy simulation 136 complete.
# UCS simulation 136 complete.
# A* simulation 136 complete.
# Simulation 136 complete.
#
# Starting simulation 137.
# DFS simulation 137 complete.
# BFS simulation 137 timed out.
# Greedy simulation 137 complete.
# UCS simulation 137 complete.
# A* simulation 137 complete.
# Simulation 137 complete.
#
# Starting simulation 138.
# DFS simulation 138 complete.
# BFS simulation 138 complete.
# Greedy simulation 138 complete.
# UCS simulation 138 complete.
# A* simulation 138 complete.
# Simulation 138 complete.
#
# Starting simulation 139.
# DFS simulation 139 encountered an empty list.
# BFS simulation 139 complete.
# Greedy simulation 139 complete.
# UCS simulation 139 complete.
# A* simulation 139 complete.
# Simulation 139 complete.
#
# Starting simulation 140.
# DFS simulation 140 encountered an empty list.
# BFS simulation 140 encountered an empty list.
# Greedy simulation 140 encountered an empty list.
# UCS simulation 140 encountered an empty list.
# A* simulation 140 encountered an empty list.
# Simulation 140 complete.
#
# Starting simulation 141.
# DFS simulation 141 encountered an empty list.
# BFS simulation 141 encountered an empty list.
# Greedy simulation 141 encountered an empty list.
# UCS simulation 141 encountered an empty list.
# A* simulation 141 encountered an empty list.
# Simulation 141 complete.
#
# Starting simulation 142.
# DFS simulation 142 encountered an empty list.
# BFS simulation 142 complete.
# Greedy simulation 142 complete.
# UCS simulation 142 complete.
# A* simulation 142 complete.
# Simulation 142 complete.
#
# Starting simulation 143.
# DFS simulation 143 complete.
# BFS simulation 143 timed out.
# Greedy simulation 143 complete.
# UCS simulation 143 complete.
# A* simulation 143 complete.
# Simulation 143 complete.
#
# Starting simulation 144.
# DFS simulation 144 complete.
# BFS simulation 144 timed out.
# Greedy simulation 144 complete.
# UCS simulation 144 complete.
# A* simulation 144 complete.
# Simulation 144 complete.
#
# Starting simulation 145.
# DFS simulation 145 encountered an empty list.
# BFS simulation 145 timed out.
# Greedy simulation 145 complete.
# UCS simulation 145 complete.
# A* simulation 145 complete.
# Simulation 145 complete.
#
# Starting simulation 146.
# DFS simulation 146 complete.
# BFS simulation 146 complete.
# Greedy simulation 146 complete.
# UCS simulation 146 complete.
# A* simulation 146 complete.
# Simulation 146 complete.
#
# Starting simulation 147.
# DFS simulation 147 complete.
# BFS simulation 147 timed out.
# Greedy simulation 147 complete.
# UCS simulation 147 complete.
# A* simulation 147 complete.
# Simulation 147 complete.
#
# Starting simulation 148.
# DFS simulation 148 complete.
# BFS simulation 148 timed out.
# Greedy simulation 148 complete.
# UCS simulation 148 complete.
# A* simulation 148 complete.
# Simulation 148 complete.
#
# Starting simulation 149.
# DFS simulation 149 encountered an empty list.
# BFS simulation 149 complete.
# Greedy simulation 149 complete.
# UCS simulation 149 complete.
# A* simulation 149 complete.
# Simulation 149 complete.
#
# Starting simulation 150.
# DFS simulation 150 complete.
# BFS simulation 150 timed out.
# Greedy simulation 150 complete.
# UCS simulation 150 complete.
# A* simulation 150 complete.
# Simulation 150 complete.
#
# Starting simulation 151.
# DFS simulation 151 complete.
# BFS simulation 151 timed out.
# Greedy simulation 151 complete.
# UCS simulation 151 complete.
# A* simulation 151 complete.
# Simulation 151 complete.
#
# Starting simulation 152.
# DFS simulation 152 complete.
# BFS simulation 152 complete.
# Greedy simulation 152 complete.
# UCS simulation 152 complete.
# A* simulation 152 complete.
# Simulation 152 complete.
#
# Starting simulation 153.
# DFS simulation 153 complete.
# BFS simulation 153 timed out.
# Greedy simulation 153 complete.
# UCS simulation 153 complete.
# A* simulation 153 complete.
# Simulation 153 complete.
#
# Starting simulation 154.
# DFS simulation 154 complete.
# BFS simulation 154 timed out.
# Greedy simulation 154 complete.
# UCS simulation 154 complete.
# A* simulation 154 complete.
# Simulation 154 complete.
#
# Starting simulation 155.
# DFS simulation 155 complete.
# BFS simulation 155 timed out.
# Greedy simulation 155 complete.
# UCS simulation 155 complete.
# A* simulation 155 complete.
# Simulation 155 complete.
#
# Starting simulation 156.
# DFS simulation 156 complete.
# BFS simulation 156 timed out.
# Greedy simulation 156 complete.
# UCS simulation 156 complete.
# A* simulation 156 complete.
# Simulation 156 complete.
#
# Starting simulation 157.
# DFS simulation 157 encountered an empty list.
# BFS simulation 157 encountered an empty list.
# Greedy simulation 157 encountered an empty list.
# UCS simulation 157 encountered an empty list.
# A* simulation 157 encountered an empty list.
# Simulation 157 complete.
#
# Starting simulation 158.
# DFS simulation 158 complete.
# BFS simulation 158 timed out.
# Greedy simulation 158 complete.
# UCS simulation 158 complete.
# A* simulation 158 complete.
# Simulation 158 complete.
#
# Starting simulation 159.
# DFS simulation 159 complete.
# BFS simulation 159 timed out.
# Greedy simulation 159 complete.
# UCS simulation 159 complete.
# A* simulation 159 complete.
# Simulation 159 complete.
#
# Starting simulation 160.
# DFS simulation 160 encountered an empty list.
# BFS simulation 160 complete.
# Greedy simulation 160 complete.
# UCS simulation 160 complete.
# A* simulation 160 complete.
# Simulation 160 complete.
#
# Starting simulation 161.
# DFS simulation 161 encountered an empty list.
# BFS simulation 161 timed out.
# Greedy simulation 161 complete.
# UCS simulation 161 complete.
# A* simulation 161 complete.
# Simulation 161 complete.
#
# Starting simulation 162.
# DFS simulation 162 complete.
# BFS simulation 162 timed out.
# Greedy simulation 162 complete.
# UCS simulation 162 complete.
# A* simulation 162 complete.
# Simulation 162 complete.
#
# Starting simulation 163.
# DFS simulation 163 complete.
# BFS simulation 163 timed out.
# Greedy simulation 163 complete.
# UCS simulation 163 complete.
# A* simulation 163 complete.
# Simulation 163 complete.
#
# Starting simulation 164.
# DFS simulation 164 complete.
# BFS simulation 164 timed out.
# Greedy simulation 164 complete.
# UCS simulation 164 complete.
# A* simulation 164 complete.
# Simulation 164 complete.
#
# Starting simulation 165.
# DFS simulation 165 encountered an empty list.
# BFS simulation 165 encountered an empty list.
# Greedy simulation 165 encountered an empty list.
# UCS simulation 165 encountered an empty list.
# A* simulation 165 encountered an empty list.
# Simulation 165 complete.
#
# Starting simulation 166.
# DFS simulation 166 complete.
# BFS simulation 166 complete.
# Greedy simulation 166 complete.
# UCS simulation 166 complete.
# A* simulation 166 complete.
# Simulation 166 complete.
#
# Starting simulation 167.
# DFS simulation 167 complete.
# BFS simulation 167 timed out.
# Greedy simulation 167 complete.
# UCS simulation 167 complete.
# A* simulation 167 complete.
# Simulation 167 complete.
#
# Starting simulation 168.
# DFS simulation 168 complete.
# BFS simulation 168 complete.
# Greedy simulation 168 complete.
# UCS simulation 168 complete.
# A* simulation 168 complete.
# Simulation 168 complete.
#
# Starting simulation 169.
# DFS simulation 169 complete.
# BFS simulation 169 timed out.
# Greedy simulation 169 complete.
# UCS simulation 169 complete.
# A* simulation 169 complete.
# Simulation 169 complete.
#
# Starting simulation 170.
# DFS simulation 170 complete.
# BFS simulation 170 timed out.
# Greedy simulation 170 complete.
# UCS simulation 170 complete.
# A* simulation 170 complete.
# Simulation 170 complete.
#
# Starting simulation 171.
# DFS simulation 171 encountered an empty list.
# BFS simulation 171 encountered an empty list.
# Greedy simulation 171 encountered an empty list.
# UCS simulation 171 encountered an empty list.
# A* simulation 171 encountered an empty list.
# Simulation 171 complete.
#
# Starting simulation 172.
# DFS simulation 172 complete.
# BFS simulation 172 timed out.
# Greedy simulation 172 complete.
# UCS simulation 172 complete.
# A* simulation 172 complete.
# Simulation 172 complete.
#
# Starting simulation 173.
# DFS simulation 173 encountered an empty list.
# BFS simulation 173 encountered an empty list.
# Greedy simulation 173 encountered an empty list.
# UCS simulation 173 encountered an empty list.
# A* simulation 173 encountered an empty list.
# Simulation 173 complete.
#
# Starting simulation 174.
# DFS simulation 174 encountered an empty list.
# BFS simulation 174 complete.
# Greedy simulation 174 complete.
# UCS simulation 174 complete.
# A* simulation 174 complete.
# Simulation 174 complete.
#
# Starting simulation 175.
# DFS simulation 175 complete.
# BFS simulation 175 timed out.
# Greedy simulation 175 complete.
# UCS simulation 175 complete.
# A* simulation 175 complete.
# Simulation 175 complete.
#
# Starting simulation 176.
# DFS simulation 176 complete.
# BFS simulation 176 timed out.
# Greedy simulation 176 complete.
# UCS simulation 176 complete.
# A* simulation 176 complete.
# Simulation 176 complete.
#
# Starting simulation 177.
# DFS simulation 177 complete.
# BFS simulation 177 timed out.
# Greedy simulation 177 complete.
# UCS simulation 177 complete.
# A* simulation 177 complete.
# Simulation 177 complete.
#
# Starting simulation 178.
# DFS simulation 178 complete.
# BFS simulation 178 timed out.
# Greedy simulation 178 complete.
# UCS simulation 178 complete.
# A* simulation 178 complete.
# Simulation 178 complete.
#
# Starting simulation 179.
# DFS simulation 179 complete.
# BFS simulation 179 timed out.
# Greedy simulation 179 complete.
# UCS simulation 179 complete.
# A* simulation 179 complete.
# Simulation 179 complete.
#
# Starting simulation 180.
# DFS simulation 180 complete.
# BFS simulation 180 timed out.
# Greedy simulation 180 complete.
# UCS simulation 180 complete.
# A* simulation 180 complete.
# Simulation 180 complete.
#
# Starting simulation 181.
# DFS simulation 181 complete.
# BFS simulation 181 timed out.
# Greedy simulation 181 complete.
# UCS simulation 181 complete.
# A* simulation 181 complete.
# Simulation 181 complete.
#
# Starting simulation 182.
# DFS simulation 182 complete.
# BFS simulation 182 timed out.
# Greedy simulation 182 complete.
# UCS simulation 182 complete.
# A* simulation 182 complete.
# Simulation 182 complete.
#
# Starting simulation 183.
# DFS simulation 183 encountered an empty list.
# BFS simulation 183 complete.
# Greedy simulation 183 complete.
# UCS simulation 183 complete.
# A* simulation 183 complete.
# Simulation 183 complete.
#
# Starting simulation 184.
# DFS simulation 184 complete.
# BFS simulation 184 timed out.
# Greedy simulation 184 complete.
# UCS simulation 184 complete.
# A* simulation 184 complete.
# Simulation 184 complete.
#
# Starting simulation 185.
# DFS simulation 185 complete.
# BFS simulation 185 timed out.
# Greedy simulation 185 complete.
# UCS simulation 185 complete.
# A* simulation 185 complete.
# Simulation 185 complete.
#
# Starting simulation 186.
# DFS simulation 186 complete.
# BFS simulation 186 timed out.
# Greedy simulation 186 complete.
# UCS simulation 186 complete.
# A* simulation 186 complete.
# Simulation 186 complete.
#
# Starting simulation 187.
# DFS simulation 187 complete.
# BFS simulation 187 timed out.
# Greedy simulation 187 complete.
# UCS simulation 187 complete.
# A* simulation 187 complete.
# Simulation 187 complete.
#
# Starting simulation 188.
# DFS simulation 188 complete.
# BFS simulation 188 timed out.
# Greedy simulation 188 complete.
# UCS simulation 188 complete.
# A* simulation 188 complete.
# Simulation 188 complete.
#
# Starting simulation 189.
# DFS simulation 189 encountered an empty list.
# BFS simulation 189 timed out.
# Greedy simulation 189 complete.
# UCS simulation 189 complete.
# A* simulation 189 complete.
# Simulation 189 complete.
#
# Starting simulation 190.
# DFS simulation 190 complete.
# BFS simulation 190 timed out.
# Greedy simulation 190 complete.
# UCS simulation 190 complete.
# A* simulation 190 complete.
# Simulation 190 complete.
#
# Starting simulation 191.
# DFS simulation 191 complete.
# BFS simulation 191 timed out.
# Greedy simulation 191 complete.
# UCS simulation 191 complete.
# A* simulation 191 complete.
# Simulation 191 complete.
#
# Starting simulation 192.
# DFS simulation 192 complete.
# BFS simulation 192 timed out.
# Greedy simulation 192 complete.
# UCS simulation 192 complete.
# A* simulation 192 complete.
# Simulation 192 complete.
#
# Starting simulation 193.
# DFS simulation 193 complete.
# BFS simulation 193 timed out.
# Greedy simulation 193 complete.
# UCS simulation 193 complete.
# A* simulation 193 complete.
# Simulation 193 complete.
#
# Starting simulation 194.
# DFS simulation 194 complete.
# BFS simulation 194 timed out.
# Greedy simulation 194 complete.
# UCS simulation 194 complete.
# A* simulation 194 complete.
# Simulation 194 complete.
#
# Starting simulation 195.
# DFS simulation 195 complete.
# BFS simulation 195 timed out.
# Greedy simulation 195 complete.
# UCS simulation 195 complete.
# A* simulation 195 complete.
# Simulation 195 complete.
#
# Starting simulation 196.
# DFS simulation 196 complete.
# BFS simulation 196 timed out.
# Greedy simulation 196 complete.
# UCS simulation 196 complete.
# A* simulation 196 complete.
# Simulation 196 complete.
#
# Starting simulation 197.
# DFS simulation 197 complete.
# BFS simulation 197 timed out.
# Greedy simulation 197 complete.
# UCS simulation 197 complete.
# A* simulation 197 complete.
# Simulation 197 complete.
#
# Starting simulation 198.
# DFS simulation 198 complete.
# BFS simulation 198 complete.
# Greedy simulation 198 complete.
# UCS simulation 198 complete.
# A* simulation 198 complete.
# Simulation 198 complete.
#
# Starting simulation 199.
# DFS simulation 199 encountered an empty list.
# BFS simulation 199 complete.
# Greedy simulation 199 complete.
# UCS simulation 199 complete.
# A* simulation 199 complete.
# Simulation 199 complete.
#
# Starting simulation 200.
# DFS simulation 200 complete.
# BFS simulation 200 complete.
# Greedy simulation 200 complete.
# UCS simulation 200 complete.
# A* simulation 200 complete.
# Simulation 200 complete.
#
# Starting simulation 201.
# DFS simulation 201 complete.
# BFS simulation 201 timed out.
# Greedy simulation 201 complete.
# UCS simulation 201 complete.
# A* simulation 201 complete.
# Simulation 201 complete.
#
# Starting simulation 202.
# DFS simulation 202 complete.
# BFS simulation 202 complete.
# Greedy simulation 202 complete.
# UCS simulation 202 complete.
# A* simulation 202 complete.
# Simulation 202 complete.
#
# Starting simulation 203.
# DFS simulation 203 complete.
# BFS simulation 203 timed out.
# Greedy simulation 203 complete.
# UCS simulation 203 complete.
# A* simulation 203 complete.
# Simulation 203 complete.
#
# Starting simulation 204.
# DFS simulation 204 complete.
# BFS simulation 204 timed out.
# Greedy simulation 204 complete.
# UCS simulation 204 complete.
# A* simulation 204 complete.
# Simulation 204 complete.
#
# Starting simulation 205.
# DFS simulation 205 complete.
# BFS simulation 205 timed out.
# Greedy simulation 205 complete.
# UCS simulation 205 complete.
# A* simulation 205 complete.
# Simulation 205 complete.
#
# Starting simulation 206.
# DFS simulation 206 complete.
# BFS simulation 206 timed out.
# Greedy simulation 206 complete.
# UCS simulation 206 complete.
# A* simulation 206 complete.
# Simulation 206 complete.
#
# Starting simulation 207.
# DFS simulation 207 complete.
# BFS simulation 207 timed out.
# Greedy simulation 207 complete.
# UCS simulation 207 timed out.
# A* simulation 207 complete.
# Simulation 207 complete.
#
# Starting simulation 208.
# DFS simulation 208 encountered an empty list.
# BFS simulation 208 complete.
# Greedy simulation 208 complete.
# UCS simulation 208 complete.
# A* simulation 208 complete.
# Simulation 208 complete.
#
# Starting simulation 209.
# DFS simulation 209 complete.
# BFS simulation 209 timed out.
# Greedy simulation 209 complete.
# UCS simulation 209 complete.
# A* simulation 209 complete.
# Simulation 209 complete.
#
# Starting simulation 210.
# DFS simulation 210 complete.
# BFS simulation 210 timed out.
# Greedy simulation 210 complete.
# UCS simulation 210 timed out.
# A* simulation 210 complete.
# Simulation 210 complete.
#
# Starting simulation 211.
# DFS simulation 211 complete.
# BFS simulation 211 timed out.
# Greedy simulation 211 complete.
# UCS simulation 211 complete.
# A* simulation 211 complete.
# Simulation 211 complete.
#
# Starting simulation 212.
# DFS simulation 212 complete.
# BFS simulation 212 timed out.
# Greedy simulation 212 complete.
# UCS simulation 212 complete.
# A* simulation 212 complete.
# Simulation 212 complete.
#
# Starting simulation 213.
# DFS simulation 213 complete.
# BFS simulation 213 complete.
# Greedy simulation 213 complete.
# UCS simulation 213 complete.
# A* simulation 213 complete.
# Simulation 213 complete.
#
# Starting simulation 214.
# DFS simulation 214 encountered an empty list.
# BFS simulation 214 timed out.
# Greedy simulation 214 complete.
# UCS simulation 214 complete.
# A* simulation 214 complete.
# Simulation 214 complete.
#
# Starting simulation 215.
# DFS simulation 215 encountered an empty list.
# BFS simulation 215 complete.
# Greedy simulation 215 complete.
# UCS simulation 215 complete.
# A* simulation 215 complete.
# Simulation 215 complete.
#
# Starting simulation 216.
# DFS simulation 216 complete.
# BFS simulation 216 timed out.
# Greedy simulation 216 complete.
# UCS simulation 216 complete.
# A* simulation 216 complete.
# Simulation 216 complete.
#
# Starting simulation 217.
# DFS simulation 217 complete.
# BFS simulation 217 timed out.
# Greedy simulation 217 complete.
# UCS simulation 217 complete.
# A* simulation 217 complete.
# Simulation 217 complete.
#
# Starting simulation 218.
# DFS simulation 218 encountered an empty list.
# BFS simulation 218 encountered an empty list.
# Greedy simulation 218 encountered an empty list.
# UCS simulation 218 encountered an empty list.
# A* simulation 218 encountered an empty list.
# Simulation 218 complete.
#
# Starting simulation 219.
# DFS simulation 219 complete.
# BFS simulation 219 timed out.
# Greedy simulation 219 complete.
# UCS simulation 219 complete.
# A* simulation 219 complete.
# Simulation 219 complete.
#
# Starting simulation 220.
# DFS simulation 220 complete.
# BFS simulation 220 timed out.
# Greedy simulation 220 complete.
# UCS simulation 220 complete.
# A* simulation 220 complete.
# Simulation 220 complete.
#
# Starting simulation 221.
# DFS simulation 221 complete.
# BFS simulation 221 timed out.
# Greedy simulation 221 complete.
# UCS simulation 221 complete.
# A* simulation 221 complete.
# Simulation 221 complete.
#
# Starting simulation 222.
# DFS simulation 222 complete.
# BFS simulation 222 timed out.
# Greedy simulation 222 complete.
# UCS simulation 222 complete.
# A* simulation 222 complete.
# Simulation 222 complete.
#
# Starting simulation 223.
# DFS simulation 223 complete.
# BFS simulation 223 timed out.
# Greedy simulation 223 complete.
# UCS simulation 223 complete.
# A* simulation 223 complete.
# Simulation 223 complete.
#
# Starting simulation 224.
# DFS simulation 224 complete.
# BFS simulation 224 timed out.
# Greedy simulation 224 complete.
# UCS simulation 224 complete.
# A* simulation 224 complete.
# Simulation 224 complete.
#
# Starting simulation 225.
# DFS simulation 225 complete.
# BFS simulation 225 timed out.
# Greedy simulation 225 complete.
# UCS simulation 225 complete.
# A* simulation 225 complete.
# Simulation 225 complete.
#
# Starting simulation 226.
# DFS simulation 226 complete.
# BFS simulation 226 complete.
# Greedy simulation 226 complete.
# UCS simulation 226 complete.
# A* simulation 226 complete.
# Simulation 226 complete.
#
# Starting simulation 227.
# DFS simulation 227 complete.
# BFS simulation 227 timed out.
# Greedy simulation 227 complete.
# UCS simulation 227 complete.
# A* simulation 227 complete.
# Simulation 227 complete.
#
# Starting simulation 228.
# DFS simulation 228 encountered an empty list.
# BFS simulation 228 timed out.
# Greedy simulation 228 complete.
# UCS simulation 228 complete.
# A* simulation 228 complete.
# Simulation 228 complete.
#
# Starting simulation 229.
# DFS simulation 229 complete.
# BFS simulation 229 timed out.
# Greedy simulation 229 complete.
# UCS simulation 229 complete.
# A* simulation 229 complete.
# Simulation 229 complete.
#
# Starting simulation 230.
# DFS simulation 230 complete.
# BFS simulation 230 complete.
# Greedy simulation 230 complete.
# UCS simulation 230 complete.
# A* simulation 230 complete.
# Simulation 230 complete.
#
# Starting simulation 231.
# DFS simulation 231 complete.
# BFS simulation 231 timed out.
# Greedy simulation 231 complete.
# UCS simulation 231 complete.
# A* simulation 231 complete.
# Simulation 231 complete.
#
# Starting simulation 232.
# DFS simulation 232 complete.
# BFS simulation 232 timed out.
# Greedy simulation 232 complete.
# UCS simulation 232 complete.
# A* simulation 232 complete.
# Simulation 232 complete.
#
# Starting simulation 233.
# DFS simulation 233 complete.
# BFS simulation 233 timed out.
# Greedy simulation 233 complete.
# UCS simulation 233 complete.
# A* simulation 233 complete.
# Simulation 233 complete.
#
# Starting simulation 234.
# DFS simulation 234 encountered an empty list.
# BFS simulation 234 encountered an empty list.
# Greedy simulation 234 encountered an empty list.
# UCS simulation 234 encountered an empty list.
# A* simulation 234 encountered an empty list.
# Simulation 234 complete.
#
# Starting simulation 235.
# DFS simulation 235 complete.
# BFS simulation 235 timed out.
# Greedy simulation 235 complete.
# UCS simulation 235 complete.
# A* simulation 235 complete.
# Simulation 235 complete.
#
# Starting simulation 236.
# DFS simulation 236 complete.
# BFS simulation 236 timed out.
# Greedy simulation 236 complete.
# UCS simulation 236 complete.
# A* simulation 236 complete.
# Simulation 236 complete.
#
# Starting simulation 237.
# DFS simulation 237 complete.
# BFS simulation 237 timed out.
# Greedy simulation 237 complete.
# UCS simulation 237 complete.
# A* simulation 237 complete.
# Simulation 237 complete.
#
# Starting simulation 238.
# DFS simulation 238 complete.
# BFS simulation 238 timed out.
# Greedy simulation 238 complete.
# UCS simulation 238 complete.
# A* simulation 238 complete.
# Simulation 238 complete.
#
# Starting simulation 239.
# DFS simulation 239 complete.
# BFS simulation 239 timed out.
# Greedy simulation 239 complete.
# UCS simulation 239 complete.
# A* simulation 239 complete.
# Simulation 239 complete.
#
# Starting simulation 240.
# DFS simulation 240 complete.
# BFS simulation 240 timed out.
# Greedy simulation 240 complete.
# UCS simulation 240 complete.
# A* simulation 240 complete.
# Simulation 240 complete.
#
# Starting simulation 241.
# DFS simulation 241 complete.
# BFS simulation 241 timed out.
# Greedy simulation 241 complete.
# UCS simulation 241 complete.
# A* simulation 241 complete.
# Simulation 241 complete.
#
# Starting simulation 242.
# DFS simulation 242 complete.
# BFS simulation 242 complete.
# Greedy simulation 242 complete.
# UCS simulation 242 complete.
# A* simulation 242 complete.
# Simulation 242 complete.
#
# Starting simulation 243.
# DFS simulation 243 complete.
# BFS simulation 243 timed out.
# Greedy simulation 243 complete.
# UCS simulation 243 complete.
# A* simulation 243 complete.
# Simulation 243 complete.
#
# Starting simulation 244.
# DFS simulation 244 encountered an empty list.
# BFS simulation 244 timed out.
# Greedy simulation 244 complete.
# UCS simulation 244 complete.
# A* simulation 244 complete.
# Simulation 244 complete.
#
# Starting simulation 245.
# DFS simulation 245 complete.
# BFS simulation 245 timed out.
# Greedy simulation 245 complete.
# UCS simulation 245 complete.
# A* simulation 245 complete.
# Simulation 245 complete.
#
# Starting simulation 246.
# DFS simulation 246 complete.
# BFS simulation 246 timed out.
# Greedy simulation 246 complete.
# UCS simulation 246 complete.
# A* simulation 246 complete.
# Simulation 246 complete.
#
# Starting simulation 247.
# DFS simulation 247 complete.
# BFS simulation 247 complete.
# Greedy simulation 247 complete.
# UCS simulation 247 complete.
# A* simulation 247 complete.
# Simulation 247 complete.
#
# Starting simulation 248.
# DFS simulation 248 complete.
# BFS simulation 248 timed out.
# Greedy simulation 248 complete.
# UCS simulation 248 complete.
# A* simulation 248 complete.
# Simulation 248 complete.
#
# Starting simulation 249.
# DFS simulation 249 complete.
# BFS simulation 249 timed out.
# Greedy simulation 249 complete.
# UCS simulation 249 complete.
# A* simulation 249 complete.
# Simulation 249 complete.
#
# Starting simulation 250.
# DFS simulation 250 complete.
# BFS simulation 250 timed out.
# Greedy simulation 250 complete.
# UCS simulation 250 complete.
# A* simulation 250 complete.
# Simulation 250 complete.
#
# Starting simulation 251.
# DFS simulation 251 complete.
# BFS simulation 251 complete.
# Greedy simulation 251 complete.
# UCS simulation 251 complete.
# A* simulation 251 complete.
# Simulation 251 complete.
#
# Starting simulation 252.
# DFS simulation 252 complete.
# BFS simulation 252 complete.
# Greedy simulation 252 complete.
# UCS simulation 252 complete.
# A* simulation 252 complete.
# Simulation 252 complete.
#
# Starting simulation 253.
# DFS simulation 253 complete.
# BFS simulation 253 timed out.
# Greedy simulation 253 complete.
# UCS simulation 253 complete.
# A* simulation 253 complete.
# Simulation 253 complete.
#
# Starting simulation 254.
# DFS simulation 254 complete.
# BFS simulation 254 timed out.
# Greedy simulation 254 complete.
# UCS simulation 254 complete.
# A* simulation 254 complete.
# Simulation 254 complete.
#
# Starting simulation 255.
# DFS simulation 255 complete.
# BFS simulation 255 timed out.
# Greedy simulation 255 complete.
# UCS simulation 255 complete.
# A* simulation 255 complete.
# Simulation 255 complete.
#
# Starting simulation 256.
# DFS simulation 256 complete.
# BFS simulation 256 timed out.
# Greedy simulation 256 complete.
# UCS simulation 256 complete.
# A* simulation 256 complete.
# Simulation 256 complete.
#
# Starting simulation 257.
# DFS simulation 257 complete.
# BFS simulation 257 complete.
# Greedy simulation 257 complete.
# UCS simulation 257 complete.
# A* simulation 257 complete.
# Simulation 257 complete.
#
# Starting simulation 258.
# DFS simulation 258 encountered an empty list.
# BFS simulation 258 timed out.
# Greedy simulation 258 complete.
# UCS simulation 258 complete.
# A* simulation 258 complete.
# Simulation 258 complete.
#
# Starting simulation 259.
# DFS simulation 259 complete.
# BFS simulation 259 timed out.
# Greedy simulation 259 complete.
# UCS simulation 259 complete.
# A* simulation 259 complete.
# Simulation 259 complete.
#
# Starting simulation 260.
# DFS simulation 260 complete.
# BFS simulation 260 timed out.
# Greedy simulation 260 complete.
# UCS simulation 260 complete.
# A* simulation 260 complete.
# Simulation 260 complete.
#
# Starting simulation 261.
# DFS simulation 261 encountered an empty list.
# BFS simulation 261 complete.
# Greedy simulation 261 complete.
# UCS simulation 261 complete.
# A* simulation 261 complete.
# Simulation 261 complete.
#
# Starting simulation 262.
# DFS simulation 262 complete.
# BFS simulation 262 complete.
# Greedy simulation 262 complete.
# UCS simulation 262 complete.
# A* simulation 262 complete.
# Simulation 262 complete.
#
# Starting simulation 263.
# DFS simulation 263 complete.
# BFS simulation 263 timed out.
# Greedy simulation 263 complete.
# UCS simulation 263 complete.
# A* simulation 263 complete.
# Simulation 263 complete.
#
# Starting simulation 264.
# DFS simulation 264 complete.
# BFS simulation 264 timed out.
# Greedy simulation 264 complete.
# UCS simulation 264 complete.
# A* simulation 264 complete.
# Simulation 264 complete.
#
# Starting simulation 265.
# DFS simulation 265 complete.
# BFS simulation 265 timed out.
# Greedy simulation 265 complete.
# UCS simulation 265 complete.
# A* simulation 265 complete.
# Simulation 265 complete.
#
# Starting simulation 266.
# DFS simulation 266 complete.
# BFS simulation 266 timed out.
# Greedy simulation 266 complete.
# UCS simulation 266 complete.
# A* simulation 266 complete.
# Simulation 266 complete.
#
# Starting simulation 267.
# DFS simulation 267 complete.
# BFS simulation 267 complete.
# Greedy simulation 267 complete.
# UCS simulation 267 complete.
# A* simulation 267 complete.
# Simulation 267 complete.
#
# Starting simulation 268.
# DFS simulation 268 complete.
# BFS simulation 268 timed out.
# Greedy simulation 268 complete.
# UCS simulation 268 complete.
# A* simulation 268 complete.
# Simulation 268 complete.
#
# Starting simulation 269.
# DFS simulation 269 complete.
# BFS simulation 269 timed out.
# Greedy simulation 269 complete.
# UCS simulation 269 complete.
# A* simulation 269 complete.
# Simulation 269 complete.
#
# Starting simulation 270.
# DFS simulation 270 complete.
# BFS simulation 270 timed out.
# Greedy simulation 270 complete.
# UCS simulation 270 complete.
# A* simulation 270 complete.
# Simulation 270 complete.
#
# Starting simulation 271.
# DFS simulation 271 encountered an empty list.
# BFS simulation 271 timed out.
# Greedy simulation 271 complete.
# UCS simulation 271 complete.
# A* simulation 271 complete.
# Simulation 271 complete.
#
# Starting simulation 272.
# DFS simulation 272 complete.
# BFS simulation 272 timed out.
# Greedy simulation 272 complete.
# UCS simulation 272 complete.
# A* simulation 272 complete.
# Simulation 272 complete.
#
# Starting simulation 273.
# DFS simulation 273 complete.
# BFS simulation 273 timed out.
# Greedy simulation 273 complete.
# UCS simulation 273 complete.
# A* simulation 273 complete.
# Simulation 273 complete.
#
# Starting simulation 274.
# DFS simulation 274 complete.
# BFS simulation 274 timed out.
# Greedy simulation 274 complete.
# UCS simulation 274 complete.
# A* simulation 274 complete.
# Simulation 274 complete.
#
# Starting simulation 275.
# DFS simulation 275 complete.
# BFS simulation 275 complete.
# Greedy simulation 275 complete.
# UCS simulation 275 complete.
# A* simulation 275 complete.
# Simulation 275 complete.
#
# Starting simulation 276.
# DFS simulation 276 encountered an empty list.
# BFS simulation 276 encountered an empty list.
# Greedy simulation 276 encountered an empty list.
# UCS simulation 276 encountered an empty list.
# A* simulation 276 encountered an empty list.
# Simulation 276 complete.
#
# Starting simulation 277.
# DFS simulation 277 complete.
# BFS simulation 277 timed out.
# Greedy simulation 277 complete.
# UCS simulation 277 complete.
# A* simulation 277 complete.
# Simulation 277 complete.
#
# Starting simulation 278.
# DFS simulation 278 complete.
# BFS simulation 278 timed out.
# Greedy simulation 278 complete.
# UCS simulation 278 complete.
# A* simulation 278 complete.
# Simulation 278 complete.
#
# Starting simulation 279.
# DFS simulation 279 complete.
# BFS simulation 279 complete.
# Greedy simulation 279 complete.
# UCS simulation 279 complete.
# A* simulation 279 complete.
# Simulation 279 complete.
#
# Starting simulation 280.
# DFS simulation 280 complete.
# BFS simulation 280 timed out.
# Greedy simulation 280 complete.
# UCS simulation 280 complete.
# A* simulation 280 complete.
# Simulation 280 complete.
#
# Starting simulation 281.
# DFS simulation 281 encountered an empty list.
# BFS simulation 281 encountered an empty list.
# Greedy simulation 281 encountered an empty list.
# UCS simulation 281 encountered an empty list.
# A* simulation 281 encountered an empty list.
# Simulation 281 complete.
#
# Starting simulation 282.
# DFS simulation 282 encountered an empty list.
# BFS simulation 282 timed out.
# Greedy simulation 282 complete.
# UCS simulation 282 complete.
# A* simulation 282 complete.
# Simulation 282 complete.
#
# Starting simulation 283.
# DFS simulation 283 complete.
# BFS simulation 283 complete.
# Greedy simulation 283 complete.
# UCS simulation 283 complete.
# A* simulation 283 complete.
# Simulation 283 complete.
#
# Starting simulation 284.
# DFS simulation 284 complete.
# BFS simulation 284 timed out.
# Greedy simulation 284 complete.
# UCS simulation 284 complete.
# A* simulation 284 complete.
# Simulation 284 complete.
#
# Starting simulation 285.
# DFS simulation 285 complete.
# BFS simulation 285 timed out.
# Greedy simulation 285 complete.
# UCS simulation 285 complete.
# A* simulation 285 complete.
# Simulation 285 complete.
#
# Starting simulation 286.
# DFS simulation 286 complete.
# BFS simulation 286 timed out.
# Greedy simulation 286 complete.
# UCS simulation 286 complete.
# A* simulation 286 complete.
# Simulation 286 complete.
#
# Starting simulation 287.
# DFS simulation 287 complete.
# BFS simulation 287 timed out.
# Greedy simulation 287 complete.
# UCS simulation 287 complete.
# A* simulation 287 complete.
# Simulation 287 complete.
#
# Starting simulation 288.
# DFS simulation 288 complete.
# BFS simulation 288 timed out.
# Greedy simulation 288 complete.
# UCS simulation 288 complete.
# A* simulation 288 complete.
# Simulation 288 complete.
#
# Starting simulation 289.
# DFS simulation 289 complete.
# BFS simulation 289 timed out.
# Greedy simulation 289 complete.
# UCS simulation 289 complete.
# A* simulation 289 complete.
# Simulation 289 complete.
#
# Starting simulation 290.
# DFS simulation 290 complete.
# BFS simulation 290 timed out.
# Greedy simulation 290 complete.
# UCS simulation 290 timed out.
# A* simulation 290 complete.
# Simulation 290 complete.
#
# Starting simulation 291.
# DFS simulation 291 complete.
# BFS simulation 291 timed out.
# Greedy simulation 291 complete.
# UCS simulation 291 complete.
# A* simulation 291 complete.
# Simulation 291 complete.
#
# Starting simulation 292.
# DFS simulation 292 complete.
# BFS simulation 292 timed out.
# Greedy simulation 292 complete.
# UCS simulation 292 complete.
# A* simulation 292 complete.
# Simulation 292 complete.
#
# Starting simulation 293.
# DFS simulation 293 complete.
# BFS simulation 293 timed out.
# Greedy simulation 293 complete.
# UCS simulation 293 complete.
# A* simulation 293 complete.
# Simulation 293 complete.
#
# Starting simulation 294.
# DFS simulation 294 complete.
# BFS simulation 294 timed out.
# Greedy simulation 294 complete.
# UCS simulation 294 complete.
# A* simulation 294 complete.
# Simulation 294 complete.
#
# Starting simulation 295.
# DFS simulation 295 complete.
# BFS simulation 295 timed out.
# Greedy simulation 295 complete.
# UCS simulation 295 timed out.
# A* simulation 295 complete.
# Simulation 295 complete.
#
# Starting simulation 296.
# DFS simulation 296 complete.
# BFS simulation 296 timed out.
# Greedy simulation 296 complete.
# UCS simulation 296 complete.
# A* simulation 296 complete.
# Simulation 296 complete.
#
# Starting simulation 297.
# DFS simulation 297 complete.
# BFS simulation 297 timed out.
# Greedy simulation 297 complete.
# UCS simulation 297 complete.
# A* simulation 297 complete.
# Simulation 297 complete.
#
# Starting simulation 298.
# DFS simulation 298 complete.
# BFS simulation 298 timed out.
# Greedy simulation 298 complete.
# UCS simulation 298 complete.
# A* simulation 298 complete.
# Simulation 298 complete.
#
# Starting simulation 299.
# DFS simulation 299 complete.
# BFS simulation 299 timed out.
# Greedy simulation 299 complete.
# UCS simulation 299 complete.
# A* simulation 299 complete.
# Simulation 299 complete.

# %%
alg_tests = pd.DataFrame(test_log)

# %%
alg_tests.to_csv("hakeem_tests.csv", index=False)
